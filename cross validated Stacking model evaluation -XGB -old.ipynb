# %%
import time

import pandas as pd
import numpy as np
import joblib
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
import xgboost

# %%
trainDataFrameLevel1 = pd.read_csv('./data/trainLevel1Preds.csv')
trainLabels = trainDataFrameLevel1['TARGET']
trainFeaturesLevel1 = trainDataFrameLevel1.drop(['TARGET'], axis=1)

# %%
print trainDataFrameLevel1.shape
print trainLabels.shape
print trainFeaturesLevel1.shape
np.array_equal(trainLabels.index, trainFeaturesLevel1.index)
# Out:
# (76020, 189)
# (76020,)
# (76020, 188)
# True

# %% [markdown]
# ## To include original features:

# %%
# for original data:
# load original features
trainDataFrameOrig = pd.read_csv('./data/train.csv')

# remove constant columns
colsToRemove1 = []
for col in trainDataFrameOrig.columns:
    if trainDataFrameOrig[col].std() == 0:
        colsToRemove1.append(col)

trainDataFrameOrig.drop(colsToRemove1, axis=1, inplace=True)

# remove duplicate columns
colsToRemove2 = []
columns = trainDataFrameOrig.columns
for i in range(len(columns)-1):
    v = trainDataFrameOrig[columns[i]].values
    for j in range(i+1,len(columns)):
        if np.array_equal(v,trainDataFrameOrig[columns[j]].values):
            colsToRemove2.append(columns[j])

trainDataFrameOrig.drop(colsToRemove2, axis=1, inplace=True)
trainDataFrameOrig.drop(['ID'], axis=1, inplace=True)

#trainLabels = trainDataFrame['TARGET']
trainFeaturesOriginal = trainDataFrameOrig.drop(['TARGET'], axis=1)

# %%
print trainDataFrameOrig.shape
print trainFeaturesOriginal.shape
# Out:
# (76020, 307)
# (76020, 306)

# %% [markdown]
# ## Helper to get train/validation data:

# %%
trainDataFrame = pd.concat([trainFeaturesLevel1, trainFeaturesOriginal, trainLabels], axis=1)

# %%
print trainDataFrame.shape
# Out:
# (76020, 495)

# %%
trainDataFrame.head()
# Out:
#       gbc_0     gbc_1     gbc_2     gbc_3     gbc_4     gbc_5     gbc_6  \
# 0  0.342172  0.414435  0.323783  0.449650  0.315510  0.371713  0.344857
# 1  0.212977  0.179875  0.168360  0.277437  0.185459  0.194718  0.210133
# 2  0.060077  0.056295  0.058152  0.060049  0.052826  0.065247  0.058802
# 3  0.351010  0.464450  0.381325  0.449268  0.410513  0.451058  0.449003
# 4  0.279508  0.122038  0.199128  0.211480  0.158174  0.204654  0.178540
#
#       gbc_7     gbc_8     gbc_9   ...    saldo_medio_var33_hace2  \
# 0  0.363904  0.328568  0.393100   ...                          0
# 1  0.172217  0.229657  0.183873   ...                          0
# 2  0.062107  0.054230  0.049104   ...                          0
# 3  0.489866  0.399165  0.416468   ...                          0
# 4  0.141302  0.146963  0.243928   ...                          0
#
#    saldo_medio_var33_hace3  saldo_medio_var33_ult1  saldo_medio_var33_ult3  \
# 0                        0                       0                       0
# 1                        0                       0                       0
# 2                        0                       0                       0
# 3                        0                       0                       0
# 4                        0                       0                       0
#
#    saldo_medio_var44_hace2  saldo_medio_var44_hace3  saldo_medio_var44_ult1  \
# 0                        0                        0                       0
# 1                        0                        0                       0
# 2                        0                        0                       0
# 3                        0                        0                       0
# 4                        0                        0                       0
#
#    saldo_medio_var44_ult3          var38  TARGET
# 0                       0   39205.170000       0
# 1                       0   49278.030000       0
# 2                       0   67333.770000       0
# 3                       0   64007.970000       0
# 4                       0  117310.979016       0
#
# [5 rows x 495 columns]

# %%
dataTarget0 = trainDataFrame[trainDataFrame.TARGET == 0]
dataTarget1 = trainDataFrame[trainDataFrame.TARGET == 1]
np.random.seed(1)

# %%
def getBalancedTrainAndValidationSets():
    # shuffle 
    dt0 = dataTarget0.reindex(np.random.permutation(dataTarget0.index))
    dt1 = dataTarget1.reindex(np.random.permutation(dataTarget1.index))

    trn0 = dt0[0:36500]
    trn1 = dt1[0:1500]
    trn = pd.concat([trn0, trn1])
    y_train = trn['TARGET']
    X_train = trn.drop(['TARGET'], axis=1)
        
    val0 = dt0[36500:]
    val1 = dt1[1500:]
    val = pd.concat([val0, val1])
    y_val = val['TARGET']
    X_val = val.drop(['TARGET'], axis=1)
        
    return X_train, y_train, X_val, y_val

# %%
# cross validated performance
n_folds = 20
clf = xgboost.XGBClassifier(learning_rate=0.05, n_estimators=125)
trn_scores = []
val_scores = []
start = time.time()
for i in range(n_folds):
    X_train, y_train, X_val, y_val = getBalancedTrainAndValidationSets()
    clf.fit(X_train, y_train)
    # evaluate w .predict_proba() !!!! :
    trn_score = roc_auc_score(y_train, clf.predict_proba(X_train)[:,1])
    val_score = roc_auc_score(y_val, clf.predict_proba(X_val)[:,1])
    # evaluate w .predict():
    # trn_score = roc_auc_score(y_train, clf.predict(X_train))
    # val_score = roc_auc_score(y_val, clf.predict(X_val))
    print "(%d/%d) train auc: %.4f" % (i, n_folds, trn_score)
    print "(%d/%d) validation auc: %.4f" % (i, n_folds, val_score)
    trn_scores.append(trn_score)
    val_scores.append(val_score)

print "-----------------------"
print "'%s' performance on %d fold CV:" % (clf.__name__, n_folds)
print "Train Mean: %.4f" % np.mean(trn_scores)
print "Train Std: %.4f" % np.std(trn_scores)
print "Validation Mean: %.4f" % np.mean(val_scores)
print "Validation Std: %.4f" % np.std(val_scores)
print "Total Time (mins): %.1f" % ((time.time()-start)/60.)

# %% [markdown]
# ### to use eval_metric=auc, we can use booster obj

# %%
# for original data:
# load original features
trainDataFrame = pd.read_csv('./data/train.csv')

# remove constant columns
colsToRemove1 = []
for col in trainDataFrame.columns:
    if trainDataFrame[col].std() == 0:
        colsToRemove1.append(col)

trainDataFrame.drop(colsToRemove1, axis=1, inplace=True)

# remove duplicate columns
colsToRemove2 = []
columns = trainDataFrame.columns
for i in range(len(columns)-1):
    v = trainDataFrame[columns[i]].values
    for j in range(i+1,len(columns)):
        if np.array_equal(v,trainDataFrame[columns[j]].values):
            colsToRemove2.append(columns[j])

trainDataFrame.drop(colsToRemove2, axis=1, inplace=True)
trainDataFrame.drop(['ID'], axis=1, inplace=True)

# %%
print X_train.shape
# Out:
# (38000, 494)

# %%
param = {'bst:max_depth':5, 'bst:eta':0.0202048, 'silent':1, 'objective':'binary:logistic' }
param['nthread'] = 4
param['eval_metric'] = 'auc'
num_round = 500

X_train, y_train, X_val, y_val = getBalancedTrainAndValidationSets()
dtrain = xgboost.DMatrix(X_train, label=y_train)
dtest = xgboost.DMatrix(X_val, label=y_val)
evallist  = [(dtest,'eval'), (dtrain,'train')]
clf = xgboost.train( param, dtrain, num_round, evallist )
# Out:
# [0]	eval-auc:0.841237	train-auc:0.852656
# [1]	eval-auc:0.842967	train-auc:0.855461
# [2]	eval-auc:0.842924	train-auc:0.855375
# [3]	eval-auc:0.851160	train-auc:0.864808
# [4]	eval-auc:0.851122	train-auc:0.865404
# [5]	eval-auc:0.852709	train-auc:0.867875
# [6]	eval-auc:0.853114	train-auc:0.869246
# [7]	eval-auc:0.853211	train-auc:0.869591
# [8]	eval-auc:0.853147	train-auc:0.869583
# [9]	eval-auc:0.853430	train-auc:0.870455
# [10]	eval-auc:0.853481	train-auc:0.870554
# [11]	eval-auc:0.853551	train-auc:0.870302
# [12]	eval-auc:0.854345	train-auc:0.870961
# [13]	eval-auc:0.854545	train-auc:0.871167
# [14]	eval-auc:0.854479	train-auc:0.871028
# [15]	eval-auc:0.854493	train-auc:0.871293
# [16]	eval-auc:0.854562	train-auc:0.871275
# [17]	eval-auc:0.854543	train-auc:0.871206
# [18]	eval-auc:0.854457	train-auc:0.871239
# [19]	eval-auc:0.854530	train-auc:0.871333
# [20]	eval-auc:0.854510	train-auc:0.871421
# [21]	eval-auc:0.854698	train-auc:0.871963
# [22]	eval-auc:0.854687	train-auc:0.871985
# [23]	eval-auc:0.854998	train-auc:0.872452
# [24]	eval-auc:0.855120	train-auc:0.872822
# [25]	eval-auc:0.855087	train-auc:0.873170
# [26]	eval-auc:0.855050	train-auc:0.873105
# [27]	eval-auc:0.855097	train-auc:0.873148
# [28]	eval-auc:0.855130	train-auc:0.873262
# [29]	eval-auc:0.855093	train-auc:0.873277
# [30]	eval-auc:0.855142	train-auc:0.873316
# [31]	eval-auc:0.855246	train-auc:0.873809
# [32]	eval-auc:0.855262	train-auc:0.873781
# [33]	eval-auc:0.855346	train-auc:0.874256
# [34]	eval-auc:0.855294	train-auc:0.874478
# [35]	eval-auc:0.855336	train-auc:0.874479
# [36]	eval-auc:0.855274	train-auc:0.874736
# [37]	eval-auc:0.855366	train-auc:0.875120
# [38]	eval-auc:0.855348	train-auc:0.875234
# [39]	eval-auc:0.855388	train-auc:0.875364
# [40]	eval-auc:0.855524	train-auc:0.875757
# [41]	eval-auc:0.855532	train-auc:0.875826
# [42]	eval-auc:0.855531	train-auc:0.875926
# [43]	eval-auc:0.855411	train-auc:0.876216
# [44]	eval-auc:0.855456	train-auc:0.876368
# [45]	eval-auc:0.855427	train-auc:0.876788
# [46]	eval-auc:0.855524	train-auc:0.876929
# [47]	eval-auc:0.855485	train-auc:0.876931
# [48]	eval-auc:0.855489	train-auc:0.877069
# [49]	eval-auc:0.855467	train-auc:0.877279
# [50]	eval-auc:0.855453	train-auc:0.877397
# [51]	eval-auc:0.855504	train-auc:0.877461
# [52]	eval-auc:0.855535	train-auc:0.877523
# [53]	eval-auc:0.855486	train-auc:0.877671
# [54]	eval-auc:0.856313	train-auc:0.878971
# [55]	eval-auc:0.856288	train-auc:0.879157
# [56]	eval-auc:0.856300	train-auc:0.879398
# [57]	eval-auc:0.856328	train-auc:0.879675
# [58]	eval-auc:0.856359	train-auc:0.879683
# [59]	eval-auc:0.856334	train-auc:0.879799
# [60]	eval-auc:0.856320	train-auc:0.879901
# [61]	eval-auc:0.856381	train-auc:0.879970
# [62]	eval-auc:0.856380	train-auc:0.880011
# [63]	eval-auc:0.856337	train-auc:0.880120
# [64]	eval-auc:0.856317	train-auc:0.880177
# [65]	eval-auc:0.856457	train-auc:0.880525
# [66]	eval-auc:0.856478	train-auc:0.880759
# [67]	eval-auc:0.856556	train-auc:0.880888
# [68]	eval-auc:0.856528	train-auc:0.881002
# [69]	eval-auc:0.856536	train-auc:0.881151
# [70]	eval-auc:0.856500	train-auc:0.881261
# [71]	eval-auc:0.856501	train-auc:0.881372
# [72]	eval-auc:0.856559	train-auc:0.881454
# [73]	eval-auc:0.856646	train-auc:0.881544
# [74]	eval-auc:0.856608	train-auc:0.881737
# [75]	eval-auc:0.856654	train-auc:0.881870
# [76]	eval-auc:0.856711	train-auc:0.881941
# [77]	eval-auc:0.856721	train-auc:0.882135
# [78]	eval-auc:0.856724	train-auc:0.882288
# [79]	eval-auc:0.856728	train-auc:0.882326
# [80]	eval-auc:0.856789	train-auc:0.882505
# [81]	eval-auc:0.856787	train-auc:0.882572
# [82]	eval-auc:0.856822	train-auc:0.882701
# [83]	eval-auc:0.856857	train-auc:0.882922
# [84]	eval-auc:0.856872	train-auc:0.882994
# [85]	eval-auc:0.857011	train-auc:0.883292
# [86]	eval-auc:0.857011	train-auc:0.883470
# [87]	eval-auc:0.857043	train-auc:0.883685
# [88]	eval-auc:0.857057	train-auc:0.883790
# [89]	eval-auc:0.857173	train-auc:0.883955
# [90]	eval-auc:0.857292	train-auc:0.884080
# [91]	eval-auc:0.857337	train-auc:0.884212
# [92]	eval-auc:0.857431	train-auc:0.884377
# [93]	eval-auc:0.857447	train-auc:0.884493
# [94]	eval-auc:0.857460	train-auc:0.884595
# [95]	eval-auc:0.857773	train-auc:0.884785
# [96]	eval-auc:0.857783	train-auc:0.884910
# [97]	eval-auc:0.857787	train-auc:0.885060
# [98]	eval-auc:0.857826	train-auc:0.885322
# [99]	eval-auc:0.857858	train-auc:0.885420
# [100]	eval-auc:0.857935	train-auc:0.885631
# [101]	eval-auc:0.857952	train-auc:0.885765
# [102]	eval-auc:0.858094	train-auc:0.886030
# [103]	eval-auc:0.858097	train-auc:0.886170
# [104]	eval-auc:0.858198	train-auc:0.886473
# [105]	eval-auc:0.858150	train-auc:0.886666
# [106]	eval-auc:0.858144	train-auc:0.886867
# [107]	eval-auc:0.858185	train-auc:0.886950
# [108]	eval-auc:0.858191	train-auc:0.887069
# [109]	eval-auc:0.858141	train-auc:0.887321
# [110]	eval-auc:0.858165	train-auc:0.887569
# [111]	eval-auc:0.858200	train-auc:0.887807
# [112]	eval-auc:0.858213	train-auc:0.887964
# [113]	eval-auc:0.858252	train-auc:0.888084
# [114]	eval-auc:0.858265	train-auc:0.888233
# [115]	eval-auc:0.858274	train-auc:0.888295
# [116]	eval-auc:0.858318	train-auc:0.888572
# [117]	eval-auc:0.858328	train-auc:0.888770
# [118]	eval-auc:0.858286	train-auc:0.889083
# [119]	eval-auc:0.858325	train-auc:0.889477
# [120]	eval-auc:0.858345	train-auc:0.889627
# [121]	eval-auc:0.858479	train-auc:0.890061
# [122]	eval-auc:0.858481	train-auc:0.890179
# [123]	eval-auc:0.858533	train-auc:0.890385
# [124]	eval-auc:0.858605	train-auc:0.890598
# [125]	eval-auc:0.858591	train-auc:0.890744
# [126]	eval-auc:0.858575	train-auc:0.890982
# [127]	eval-auc:0.858628	train-auc:0.891231
# [128]	eval-auc:0.858629	train-auc:0.891438
# [129]	eval-auc:0.858609	train-auc:0.891572
# [130]	eval-auc:0.858544	train-auc:0.891707
# [131]	eval-auc:0.858531	train-auc:0.891950
# [132]	eval-auc:0.858456	train-auc:0.892081
# [133]	eval-auc:0.858509	train-auc:0.892315
# [134]	eval-auc:0.858479	train-auc:0.892427
# [135]	eval-auc:0.858487	train-auc:0.892776
# [136]	eval-auc:0.858468	train-auc:0.892904
# [137]	eval-auc:0.858512	train-auc:0.893051
# [138]	eval-auc:0.858484	train-auc:0.893173
# [139]	eval-auc:0.858486	train-auc:0.893508
# [140]	eval-auc:0.858524	train-auc:0.893801
# [141]	eval-auc:0.858499	train-auc:0.893875
# [142]	eval-auc:0.858526	train-auc:0.894080
# [143]	eval-auc:0.858480	train-auc:0.894206
# [144]	eval-auc:0.858465	train-auc:0.894431
# [145]	eval-auc:0.858490	train-auc:0.894586
# [146]	eval-auc:0.858488	train-auc:0.894748
# [147]	eval-auc:0.858472	train-auc:0.894988
# [148]	eval-auc:0.858462	train-auc:0.895170
# [149]	eval-auc:0.858445	train-auc:0.895284
# [150]	eval-auc:0.858434	train-auc:0.895401
# [151]	eval-auc:0.858468	train-auc:0.895641
# [152]	eval-auc:0.858575	train-auc:0.895925
# [153]	eval-auc:0.858620	train-auc:0.896156
# [154]	eval-auc:0.858602	train-auc:0.896314
# [155]	eval-auc:0.858645	train-auc:0.896465
# [156]	eval-auc:0.858668	train-auc:0.896723
# [157]	eval-auc:0.858660	train-auc:0.896915
# [158]	eval-auc:0.858757	train-auc:0.897183
# [159]	eval-auc:0.858774	train-auc:0.897389
# [160]	eval-auc:0.858805	train-auc:0.897579
# [161]	eval-auc:0.858814	train-auc:0.897732
# [162]	eval-auc:0.858810	train-auc:0.897917
# [163]	eval-auc:0.858814	train-auc:0.898041
# [164]	eval-auc:0.858852	train-auc:0.898187
# [165]	eval-auc:0.858867	train-auc:0.898291
# [166]	eval-auc:0.858833	train-auc:0.898443
# [167]	eval-auc:0.858868	train-auc:0.898568
# [168]	eval-auc:0.858856	train-auc:0.898789
# [169]	eval-auc:0.858908	train-auc:0.898968
# [170]	eval-auc:0.858983	train-auc:0.899223
# [171]	eval-auc:0.858939	train-auc:0.899357
# [172]	eval-auc:0.859043	train-auc:0.899671
# [173]	eval-auc:0.859072	train-auc:0.899942
# [174]	eval-auc:0.859025	train-auc:0.900131
# [175]	eval-auc:0.859091	train-auc:0.900297
# [176]	eval-auc:0.859196	train-auc:0.900560
# [177]	eval-auc:0.859191	train-auc:0.900701
# [178]	eval-auc:0.859242	train-auc:0.900908
# [179]	eval-auc:0.859352	train-auc:0.901375
# [180]	eval-auc:0.859403	train-auc:0.901661
# [181]	eval-auc:0.859405	train-auc:0.901837
# [182]	eval-auc:0.859439	train-auc:0.902058
# [183]	eval-auc:0.859437	train-auc:0.902332
# [184]	eval-auc:0.859435	train-auc:0.902631
# [185]	eval-auc:0.859496	train-auc:0.902808
# [186]	eval-auc:0.859497	train-auc:0.902982
# [187]	eval-auc:0.859579	train-auc:0.903178
# [188]	eval-auc:0.859537	train-auc:0.903289
# [189]	eval-auc:0.859554	train-auc:0.903490
# [190]	eval-auc:0.859541	train-auc:0.903607
# [191]	eval-auc:0.859488	train-auc:0.903782
# [192]	eval-auc:0.859500	train-auc:0.903962
# [193]	eval-auc:0.859528	train-auc:0.904327
# [194]	eval-auc:0.859477	train-auc:0.904450
# [195]	eval-auc:0.859579	train-auc:0.904905
# [196]	eval-auc:0.859609	train-auc:0.905288
# [197]	eval-auc:0.859698	train-auc:0.905549
# [198]	eval-auc:0.859715	train-auc:0.905856
# [199]	eval-auc:0.859728	train-auc:0.905998
# [200]	eval-auc:0.859887	train-auc:0.906697
# [201]	eval-auc:0.859891	train-auc:0.906753
# [202]	eval-auc:0.859854	train-auc:0.906951
# [203]	eval-auc:0.859957	train-auc:0.907271
# [204]	eval-auc:0.860036	train-auc:0.907462
# [205]	eval-auc:0.860114	train-auc:0.907831
# [206]	eval-auc:0.860110	train-auc:0.908125
# [207]	eval-auc:0.860121	train-auc:0.908276
# [208]	eval-auc:0.860170	train-auc:0.908550
# [209]	eval-auc:0.860220	train-auc:0.908776
# [210]	eval-auc:0.860211	train-auc:0.909031
# [211]	eval-auc:0.860180	train-auc:0.909209
# [212]	eval-auc:0.860230	train-auc:0.909380
# [213]	eval-auc:0.860240	train-auc:0.909553
# [214]	eval-auc:0.860318	train-auc:0.909883
# [215]	eval-auc:0.860467	train-auc:0.910172
# [216]	eval-auc:0.860487	train-auc:0.910324
# [217]	eval-auc:0.860542	train-auc:0.910623
# [218]	eval-auc:0.860517	train-auc:0.910765
# [219]	eval-auc:0.860519	train-auc:0.910875
# [220]	eval-auc:0.860558	train-auc:0.911026
# [221]	eval-auc:0.860611	train-auc:0.911321
# [222]	eval-auc:0.860620	train-auc:0.911493
# [223]	eval-auc:0.860716	train-auc:0.911845
# [224]	eval-auc:0.860680	train-auc:0.911998
# [225]	eval-auc:0.860723	train-auc:0.912297
# [226]	eval-auc:0.860757	train-auc:0.912514
# [227]	eval-auc:0.860792	train-auc:0.912781
# [228]	eval-auc:0.860784	train-auc:0.912918
# [229]	eval-auc:0.860787	train-auc:0.913201
# [230]	eval-auc:0.860859	train-auc:0.913471
# [231]	eval-auc:0.860934	train-auc:0.913778
# [232]	eval-auc:0.860961	train-auc:0.914006
# [233]	eval-auc:0.861016	train-auc:0.914297
# [234]	eval-auc:0.861051	train-auc:0.914529
# [235]	eval-auc:0.861048	train-auc:0.914720
# [236]	eval-auc:0.861096	train-auc:0.914957
# [237]	eval-auc:0.861116	train-auc:0.915225
# [238]	eval-auc:0.861183	train-auc:0.915437
# [239]	eval-auc:0.861170	train-auc:0.915608
# [240]	eval-auc:0.861211	train-auc:0.915835
# [241]	eval-auc:0.861218	train-auc:0.916075
# [242]	eval-auc:0.861185	train-auc:0.916268
# [243]	eval-auc:0.861194	train-auc:0.916453
# [244]	eval-auc:0.861180	train-auc:0.916591
# [245]	eval-auc:0.861184	train-auc:0.916740
# [246]	eval-auc:0.861193	train-auc:0.916983
# [247]	eval-auc:0.861288	train-auc:0.917184
# [248]	eval-auc:0.861261	train-auc:0.917424
# [249]	eval-auc:0.861271	train-auc:0.917631
# [250]	eval-auc:0.861276	train-auc:0.917755
# [251]	eval-auc:0.861320	train-auc:0.917952
# [252]	eval-auc:0.861350	train-auc:0.918156
# [253]	eval-auc:0.861395	train-auc:0.918370
# [254]	eval-auc:0.861377	train-auc:0.918501
# [255]	eval-auc:0.861402	train-auc:0.918684
# [256]	eval-auc:0.861398	train-auc:0.918878
# [257]	eval-auc:0.861396	train-auc:0.919091
# [258]	eval-auc:0.861360	train-auc:0.919227
# [259]	eval-auc:0.861340	train-auc:0.919416
# [260]	eval-auc:0.861360	train-auc:0.919650
# [261]	eval-auc:0.861355	train-auc:0.919821
# [262]	eval-auc:0.861403	train-auc:0.919959
# [263]	eval-auc:0.861399	train-auc:0.920157
# [264]	eval-auc:0.861408	train-auc:0.920255
# [265]	eval-auc:0.861397	train-auc:0.920342
# [266]	eval-auc:0.861389	train-auc:0.920478
# [267]	eval-auc:0.861391	train-auc:0.920562
# [268]	eval-auc:0.861368	train-auc:0.920657
# [269]	eval-auc:0.861369	train-auc:0.920738
# [270]	eval-auc:0.861347	train-auc:0.920922
# [271]	eval-auc:0.861373	train-auc:0.921139
# [272]	eval-auc:0.861362	train-auc:0.921235
# [273]	eval-auc:0.861382	train-auc:0.921339
# [274]	eval-auc:0.861373	train-auc:0.921417
# [275]	eval-auc:0.861388	train-auc:0.921558
# [276]	eval-auc:0.861416	train-auc:0.921700
# [277]	eval-auc:0.861410	train-auc:0.921828
# [278]	eval-auc:0.861396	train-auc:0.921873
# [279]	eval-auc:0.861396	train-auc:0.921939
# [280]	eval-auc:0.861375	train-auc:0.922038
# [281]	eval-auc:0.861409	train-auc:0.922180
# [282]	eval-auc:0.861430	train-auc:0.922308
# [283]	eval-auc:0.861438	train-auc:0.922373
# [284]	eval-auc:0.861436	train-auc:0.922415
# [285]	eval-auc:0.861435	train-auc:0.922529
# [286]	eval-auc:0.861416	train-auc:0.922683
# [287]	eval-auc:0.861432	train-auc:0.922807
# [288]	eval-auc:0.861400	train-auc:0.922888
# [289]	eval-auc:0.861463	train-auc:0.923026
# [290]	eval-auc:0.861478	train-auc:0.923137
# [291]	eval-auc:0.861475	train-auc:0.923286
# [292]	eval-auc:0.861479	train-auc:0.923428
# [293]	eval-auc:0.861497	train-auc:0.923551
# [294]	eval-auc:0.861492	train-auc:0.923689
# [295]	eval-auc:0.861477	train-auc:0.923832
# [296]	eval-auc:0.861519	train-auc:0.923936
# [297]	eval-auc:0.861508	train-auc:0.923978
# [298]	eval-auc:0.861499	train-auc:0.924037
# [299]	eval-auc:0.861515	train-auc:0.924184
# [300]	eval-auc:0.861514	train-auc:0.924296
# [301]	eval-auc:0.861507	train-auc:0.924338
# [302]	eval-auc:0.861494	train-auc:0.924404
# [303]	eval-auc:0.861520	train-auc:0.924555
# [304]	eval-auc:0.861489	train-auc:0.924630
# [305]	eval-auc:0.861510	train-auc:0.924722
# [306]	eval-auc:0.861497	train-auc:0.924851
# [307]	eval-auc:0.861495	train-auc:0.924892
# [308]	eval-auc:0.861491	train-auc:0.925013
# [309]	eval-auc:0.861470	train-auc:0.925116
# [310]	eval-auc:0.861456	train-auc:0.925179
# [311]	eval-auc:0.861447	train-auc:0.925242
# [312]	eval-auc:0.861412	train-auc:0.925396
# [313]	eval-auc:0.861413	train-auc:0.925429
# [314]	eval-auc:0.861412	train-auc:0.925486
# [315]	eval-auc:0.861402	train-auc:0.925570
# [316]	eval-auc:0.861392	train-auc:0.925682
# [317]	eval-auc:0.861391	train-auc:0.925757
# [318]	eval-auc:0.861365	train-auc:0.925960
# [319]	eval-auc:0.861369	train-auc:0.926003
# [320]	eval-auc:0.861356	train-auc:0.926165
# [321]	eval-auc:0.861351	train-auc:0.926226
# [322]	eval-auc:0.861351	train-auc:0.926280
# [323]	eval-auc:0.861344	train-auc:0.926342
# [324]	eval-auc:0.861343	train-auc:0.926383
# [325]	eval-auc:0.861330	train-auc:0.926400
# [326]	eval-auc:0.861316	train-auc:0.926422
# [327]	eval-auc:0.861318	train-auc:0.926467
# [328]	eval-auc:0.861306	train-auc:0.926477
# [329]	eval-auc:0.861306	train-auc:0.926511
# [330]	eval-auc:0.861303	train-auc:0.926578
# [331]	eval-auc:0.861288	train-auc:0.926718
# [332]	eval-auc:0.861267	train-auc:0.926750
# [333]	eval-auc:0.861264	train-auc:0.926786
# [334]	eval-auc:0.861270	train-auc:0.926806
# [335]	eval-auc:0.861258	train-auc:0.926837
# [336]	eval-auc:0.861211	train-auc:0.926956
# [337]	eval-auc:0.861228	train-auc:0.926985
# [338]	eval-auc:0.861235	train-auc:0.927023
# [339]	eval-auc:0.861249	train-auc:0.927049
# [340]	eval-auc:0.861231	train-auc:0.927079
# [341]	eval-auc:0.861247	train-auc:0.927105
# [342]	eval-auc:0.861225	train-auc:0.927211
# [343]	eval-auc:0.861236	train-auc:0.927248
# [344]	eval-auc:0.861231	train-auc:0.927290
# [345]	eval-auc:0.861222	train-auc:0.927353
# [346]	eval-auc:0.861204	train-auc:0.927392
# [347]	eval-auc:0.861210	train-auc:0.927427
# [348]	eval-auc:0.861208	train-auc:0.927444
# [349]	eval-auc:0.861196	train-auc:0.927486
# [350]	eval-auc:0.861193	train-auc:0.927511
# [351]	eval-auc:0.861198	train-auc:0.927533
# [352]	eval-auc:0.861195	train-auc:0.927569
# [353]	eval-auc:0.861195	train-auc:0.927593
# [354]	eval-auc:0.861201	train-auc:0.927649
# [355]	eval-auc:0.861199	train-auc:0.927674
# [356]	eval-auc:0.861214	train-auc:0.927698
# [357]	eval-auc:0.861207	train-auc:0.927733
# [358]	eval-auc:0.861205	train-auc:0.927776
# [359]	eval-auc:0.861196	train-auc:0.927818
# [360]	eval-auc:0.861206	train-auc:0.927854
# [361]	eval-auc:0.861202	train-auc:0.927926
# [362]	eval-auc:0.861192	train-auc:0.927967
# [363]	eval-auc:0.861191	train-auc:0.928011
# [364]	eval-auc:0.861188	train-auc:0.928077
# [365]	eval-auc:0.861169	train-auc:0.928118
# [366]	eval-auc:0.861181	train-auc:0.928148
# [367]	eval-auc:0.861174	train-auc:0.928190
# [368]	eval-auc:0.861180	train-auc:0.928253
# [369]	eval-auc:0.861184	train-auc:0.928279
# [370]	eval-auc:0.861186	train-auc:0.928330
# [371]	eval-auc:0.861177	train-auc:0.928434
# [372]	eval-auc:0.861176	train-auc:0.928545
# [373]	eval-auc:0.861179	train-auc:0.928566
# [374]	eval-auc:0.861187	train-auc:0.928600
# [375]	eval-auc:0.861165	train-auc:0.928616
# [376]	eval-auc:0.861165	train-auc:0.928634
# [377]	eval-auc:0.861166	train-auc:0.928660
# [378]	eval-auc:0.861173	train-auc:0.928724
# [379]	eval-auc:0.861155	train-auc:0.928740
# [380]	eval-auc:0.861162	train-auc:0.928839
# [381]	eval-auc:0.861166	train-auc:0.928931
# [382]	eval-auc:0.861158	train-auc:0.928980
# [383]	eval-auc:0.861165	train-auc:0.929006
# [384]	eval-auc:0.861160	train-auc:0.929030
# [385]	eval-auc:0.861166	train-auc:0.929078
# [386]	eval-auc:0.861153	train-auc:0.929100
# [387]	eval-auc:0.861153	train-auc:0.929114
# [388]	eval-auc:0.861141	train-auc:0.929176
# [389]	eval-auc:0.861137	train-auc:0.929209
# [390]	eval-auc:0.861131	train-auc:0.929234
# [391]	eval-auc:0.861127	train-auc:0.929311
# [392]	eval-auc:0.861143	train-auc:0.929411
# [393]	eval-auc:0.861134	train-auc:0.929437
# [394]	eval-auc:0.861127	train-auc:0.929464
# [395]	eval-auc:0.861130	train-auc:0.929487
# [396]	eval-auc:0.861105	train-auc:0.929541
# [397]	eval-auc:0.861117	train-auc:0.929570
# [398]	eval-auc:0.861111	train-auc:0.929605
# [399]	eval-auc:0.861140	train-auc:0.929671
# [400]	eval-auc:0.861132	train-auc:0.929689
# [401]	eval-auc:0.861128	train-auc:0.929727
# [402]	eval-auc:0.861152	train-auc:0.929806
# [403]	eval-auc:0.861150	train-auc:0.929869
# [404]	eval-auc:0.861155	train-auc:0.929964
# [405]	eval-auc:0.861158	train-auc:0.930020
# [406]	eval-auc:0.861154	train-auc:0.930045
# [407]	eval-auc:0.861171	train-auc:0.930092
# [408]	eval-auc:0.861156	train-auc:0.930149
# [409]	eval-auc:0.861152	train-auc:0.930239
# [410]	eval-auc:0.861151	train-auc:0.930257
# [411]	eval-auc:0.861166	train-auc:0.930305
# [412]	eval-auc:0.861151	train-auc:0.930411
# [413]	eval-auc:0.861150	train-auc:0.930434
# [414]	eval-auc:0.861153	train-auc:0.930511
# [415]	eval-auc:0.861150	train-auc:0.930536
# [416]	eval-auc:0.861128	train-auc:0.930560
# [417]	eval-auc:0.861111	train-auc:0.930586
# [418]	eval-auc:0.861123	train-auc:0.930668
# [419]	eval-auc:0.861138	train-auc:0.930736
# [420]	eval-auc:0.861124	train-auc:0.930781
# [421]	eval-auc:0.861122	train-auc:0.930798
# [422]	eval-auc:0.861124	train-auc:0.930813
# [423]	eval-auc:0.861126	train-auc:0.930892
# [424]	eval-auc:0.861117	train-auc:0.930915
# [425]	eval-auc:0.861113	train-auc:0.930933
# [426]	eval-auc:0.861110	train-auc:0.931020
# [427]	eval-auc:0.861104	train-auc:0.931050
# [428]	eval-auc:0.861097	train-auc:0.931070
# [429]	eval-auc:0.861100	train-auc:0.931083
# [430]	eval-auc:0.861108	train-auc:0.931127
# [431]	eval-auc:0.861105	train-auc:0.931204
# [432]	eval-auc:0.861101	train-auc:0.931223
# [433]	eval-auc:0.861097	train-auc:0.931243
# [434]	eval-auc:0.861095	train-auc:0.931277
# [435]	eval-auc:0.861093	train-auc:0.931287
# [436]	eval-auc:0.861096	train-auc:0.931311
# [437]	eval-auc:0.861093	train-auc:0.931403
# [438]	eval-auc:0.861095	train-auc:0.931418
# [439]	eval-auc:0.861116	train-auc:0.931503
# [440]	eval-auc:0.861117	train-auc:0.931574
# [441]	eval-auc:0.861108	train-auc:0.931624
# [442]	eval-auc:0.861106	train-auc:0.931685
# [443]	eval-auc:0.861090	train-auc:0.931716
# [444]	eval-auc:0.861084	train-auc:0.931737
# [445]	eval-auc:0.861079	train-auc:0.931793
# [446]	eval-auc:0.861075	train-auc:0.931823
# [447]	eval-auc:0.861054	train-auc:0.931845
# [448]	eval-auc:0.861044	train-auc:0.931862
# [449]	eval-auc:0.861047	train-auc:0.931868
# [450]	eval-auc:0.861049	train-auc:0.931872
# [451]	eval-auc:0.861035	train-auc:0.931896
# [452]	eval-auc:0.861012	train-auc:0.931956
# [453]	eval-auc:0.861011	train-auc:0.931987
# [454]	eval-auc:0.860988	train-auc:0.932022
# [455]	eval-auc:0.860987	train-auc:0.932047
# [456]	eval-auc:0.860967	train-auc:0.932073
# [457]	eval-auc:0.860973	train-auc:0.932126
# [458]	eval-auc:0.860946	train-auc:0.932162
# [459]	eval-auc:0.860943	train-auc:0.932243
# [460]	eval-auc:0.860939	train-auc:0.932253
# [461]	eval-auc:0.860929	train-auc:0.932274
# [462]	eval-auc:0.860933	train-auc:0.932286
# [463]	eval-auc:0.860937	train-auc:0.932343
# [464]	eval-auc:0.860960	train-auc:0.932463
# [465]	eval-auc:0.860953	train-auc:0.932487
# [466]	eval-auc:0.860943	train-auc:0.932524
# [467]	eval-auc:0.860938	train-auc:0.932606
# [468]	eval-auc:0.860938	train-auc:0.932630
# [469]	eval-auc:0.860935	train-auc:0.932677
# [470]	eval-auc:0.860935	train-auc:0.932756
# [471]	eval-auc:0.860938	train-auc:0.932732
# [472]	eval-auc:0.860925	train-auc:0.932752
# [473]	eval-auc:0.860925	train-auc:0.932768
# [474]	eval-auc:0.860902	train-auc:0.932797
# [475]	eval-auc:0.860891	train-auc:0.932871
# [476]	eval-auc:0.860891	train-auc:0.932906
# [477]	eval-auc:0.860911	train-auc:0.932954
# [478]	eval-auc:0.860903	train-auc:0.933004
# [479]	eval-auc:0.860900	train-auc:0.933037
# [480]	eval-auc:0.860885	train-auc:0.933100
# [481]	eval-auc:0.860877	train-auc:0.933133
# [482]	eval-auc:0.860877	train-auc:0.933145
# [483]	eval-auc:0.860863	train-auc:0.933164
# [484]	eval-auc:0.860847	train-auc:0.933229
# [485]	eval-auc:0.860842	train-auc:0.933253
# [486]	eval-auc:0.860831	train-auc:0.933316
# [487]	eval-auc:0.860832	train-auc:0.933327
# [488]	eval-auc:0.860831	train-auc:0.933361
# [489]	eval-auc:0.860846	train-auc:0.933404
# [490]	eval-auc:0.860838	train-auc:0.933423
# [491]	eval-auc:0.860839	train-auc:0.933448
# [492]	eval-auc:0.860832	train-auc:0.933548
# [493]	eval-auc:0.860846	train-auc:0.933536
# [494]	eval-auc:0.860825	train-auc:0.933602
# [495]	eval-auc:0.860821	train-auc:0.933609
# [496]	eval-auc:0.860798	train-auc:0.933637
# [497]	eval-auc:0.860786	train-auc:0.933679
# [498]	eval-auc:0.860787	train-auc:0.933691
# [499]	eval-auc:0.860757	train-auc:0.933742

# %%
preds = clf.predict(xgboost.DMatrix(X_val))

# %%
roc_auc_score(y_val, preds)
# Out:
# 0.86075685374758526

# %%
len(preds)

# %%
len(preds[preds>.5])
# Out:
# 49
